# %% [markdown]
# # Time Complexity Practice Questions
#
# Solve each question and write the time complexity.

# %% [markdown]
# ## Question 1

# %%
for i in range(n):
    print(i)

# %% [markdown]
# Your Answer:

# %% [markdown]
# ## Question 2

# %%
for i in range(n):
    for j in range(n):
        print(i, j)

# %% [markdown]
# Your Answer:

# %% [markdown]
# ## Question 3

# %%
i = 1
while i < n:
    i = i * 2

# %% [markdown]
# Your Answer:

# %% [markdown]
# ## Question 4

# %%
for i in range(n):
    for j in range(10):
        print(i, j)

# %% [markdown]
# Your Answer:

# %% [markdown]
# ## Question 5

# %%
for i in range(n):
    for j in range(i):
        print(i, j)

# %% [markdown]
# Your Answer:

# %% [markdown]
# ## Question 6

# %%
def func(n):
    if n == 0:
        return
    func(n-1)
    func(n-1)

# %% [markdown]
# Your Answer:

# %% [markdown]
# ## Question 7

# %%
for i in range(n):
    print(i)

for j in range(n):
    print(j)

# %% [markdown]
# Your Answer:

# %% [markdown]
# ## Question 8

# %%
for i in range(n):
    j = 1
    while j < n:
        print(i, j)
        j *= 2

# %% [markdown]
# Your Answer:
